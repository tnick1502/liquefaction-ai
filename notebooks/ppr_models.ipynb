# %% [markdown]
# # Модели PPR (Pore Pressure Ratio)
#
# Графики по `src/math_models/ppr_models.py`. Все кривые по **одному графику**: PPR и g(N) на левой оси, поровое давление **u** — на правой (кПа).
#
# Для `logarithmic_ppr_normalized` при **A1 > A2** нужно **A2·k2 > A1·k1**, иначе экстремум **N_peak** оказывается вне области определения ln(kᵢN+1).

# %%
import sys
sys.path.insert(0, "..")

import numpy as np
from src.math_models.ppr_models import (
    cpt_pore_pressure_ma_wang,
    cpt_ppr_ma_wang,
    extended_cpt_ppr,
    logarithmic_ppr_normalized,
    logarithmic_ppr_raw,
)
from liquefaction_ai.utils import plot_curves_overlay

# %% [markdown]
# ## Сводный график

# %%
fig = plot_curves_overlay(
    curves=[
        {
            "func": cpt_ppr_ma_wang,
            "func_params": {"a": 0.5, "k": 0.05, "A": 100.0, "sigma_3": 200.0},
            "label": "Ма и Ванг — PPR(N)",
        },
        {
            "func": extended_cpt_ppr,
            "func_params": {"a": 0.3, "b": 0.3, "k": 0.05, "A": 1.0, "n_max": 500.0},
            "label": "Расширенная CPT — PPR(N)",
        },
        {
            "func": logarithmic_ppr_raw,
            "func_params": {"A1": 2.0, "A2": 1.5, "k1": 0.01, "k2": 0.1},
            "label": "Логарифмическая g(N)",
        },
        {
            "func": logarithmic_ppr_normalized,
            "func_params": {"A": 1.0, "A1": 2.0, "A2": 1.5, "k1": 0.01, "k2": 0.1},
            "label": "Нормированная PPR(N)",
        },
        {
            "func": cpt_pore_pressure_ma_wang,
            "func_params": {"a": 0.5, "k": 0.05, "A": 100.0},
            "label": "Ма и Ванг — u(N), кПа",
            "secondary_y": True,
        },
    ],
    x_range=(1, 500),
    x_arg_name="n_cycles",
    title="Сравнение моделей PPR / u(N)",
    x_label="N (число циклов)",
    y_label="PPR, g(N)",
    y_label_secondary="u (кПа)",
)
fig.show()
